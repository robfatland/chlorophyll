# %% [markdown]
# # Introduction
#
# These next few cells are Python to get set up with yodapy. First establish an account at the
# [OOI website](https://ooinet.oceanobservatories.org/#).
# Generate credentials, do not put them in a GitHub repo but
# keep them somewhere safe. Follow through these cells by un-commenting, running, and re-commenting so that
# you do not re-run them down the road when they are not necessary.

# %%
# Ensure that yodapy is installed directly from github using
# !pip install git+https://github.com/cormorack/yodapy.git

# %%
# Run this line to prepare to set up your credentials to use the OOI
# from yodapy.utils.creds import set_credentials_file

# %%
# Run this by ***carefully**** substituting actual credentials in the username and token strings
# set_credentials_file(data_source='ooi', username='OOIAPI-XXXXXXXXXXXXXX', token='XXXXXXXXXXXX')

# And once it runs: Obscure your credentials as Xs and comment this out immediately; don't re-run it!

# You can verify this worked by examining the .credentials file in ~/.yodapy: Credentials should match. Notice that 
#   this (slightly hidden) directory is directly connected to your home directory; whereas this IPython notebook 
#   is presumed to exist in a distinct directory; so there should be no chance of a GitHub push sending your 
#   credentials to GitHub.

# %% [markdown]
# AT a low level parquet breaks data in column-wise storage, many small files. Notice this is column-format, not row format as we are accustomed to in CSV files. When you read this into dask... a pandas data frame reads the entire file... but dask works on lazy eval
# so dask access to a parquet data ensemble (many of these small chunked files) is very efficient as lazy eval.
#
#
# Dask reads this data into a dask data frame (which we can consider virtualized / lazy); and a dask data frame is analogous to a
# pandas data frame with that virtualization.
#
#
# Athena in contrast is a way of doing something analogous. Athena is an AWS service running Apache Hive under the hood.
# You are charged for every query, be aware: And access protocol is a SQL query.

# %% [markdown]
# # Create your ooi instance
#
# The ooi instance will enable you to connect to data resources and get datasets.

# %%
from yodapy.datasources import OOI

# %%
ooi = OOI()
ooi.search(region='cabled', site='axial base shallow profiler', node='shallow profiler', instrument='CTD')
ooi.instruments                    # an attribute
ooi.data_availability()
# Out:
# (MainThread) Please wait while we fetch the metadata ...
#   RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample
# 0               Cabled Axial Seamount (Cabled Array)
# 1                Axial Base Shallow Profiler Mooring
# 2                           Shallow Profiler (SF03A)
# 3                                                CTD
# 4                                           streamed
# 5                                 ctdpf_sbe43_sample

# %%
# Let's move from this site to all of the others by getting all the site names
#   To see that use ooi.instruments (attribute) to see stuff only within the RCA
ooi.search(region='cabled')
# Out:
# <Data Source: OOI (116 Instrument Streams)>

# %%
ooi.sites                  # attribute, not method: ALL possible sites; but this is global exploration; not really a filter
# Out:
#      site_rd                     array_name  \
# 0   CE01ISSM              Coastal Endurance
# 1   CE01ISSP              Coastal Endurance
# 2   CE02SHBP              Coastal Endurance
# 3   CE02SHSM              Coastal Endurance
# 4   CE02SHSP              Coastal Endurance
# 5   CE04OSBP              Coastal Endurance
# 6   CE04OSPD              Coastal Endurance
# 7   CE04OSPS              Coastal Endurance
# 8   CE04OSSM              Coastal Endurance
# 10  CE06ISSM              Coastal Endurance
# 11  CE06ISSP              Coastal Endurance
# 12  CE07SHSM              Coastal Endurance
# 13  CE07SHSP              Coastal Endurance
# 14  CE09OSPM              Coastal Endurance
# 15  CE09OSSM              Coastal Endurance
# 16  CP01CNPM                Coastal Pioneer
# 17  CP01CNSM                Coastal Pioneer
# 18  CP01CNSP                Coastal Pioneer
# 19  CP02PMCI                Coastal Pioneer
# 20  CP02PMCO                Coastal Pioneer
# 21  CP02PMUI                Coastal Pioneer
# 22  CP02PMUO                Coastal Pioneer
# 23  CP03ISPM                Coastal Pioneer
# 24  CP03ISSM                Coastal Pioneer
# 25  CP03ISSP                Coastal Pioneer
# 26  CP04OSPM                Coastal Pioneer
# 27  CP04OSSM                Coastal Pioneer
# 29  GA01SUMO         Global Argentine Basin
# 30  GA02HYPM         Global Argentine Basin
# 31  GA03FLMA         Global Argentine Basin
# 32  GA03FLMB         Global Argentine Basin
# 34  GI01SUMO            Global Irminger Sea
# 35  GI02HYPM            Global Irminger Sea
# 36  GI03FLMA            Global Irminger Sea
# 37  GI03FLMB            Global Irminger Sea
# 39  GP02HYPM            Global Station Papa
# 40  GP03FLMA            Global Station Papa
# 41  GP03FLMB            Global Station Papa
# 43  GS01SUMO          Global Southern Ocean
# 44  GS02HYPM          Global Southern Ocean
# 45  GS03FLMA          Global Southern Ocean
# 46  GS03FLMB          Global Southern Ocean
# 48  RS01SBPD      Cabled Continental Margin
# 49  RS01SBPS      Cabled Continental Margin
# 50  RS01SHDR      Cabled Continental Margin
# 51  RS01SLBS      Cabled Continental Margin
# 52  RS01SUM1      Cabled Continental Margin
# 53  RS01SUM2      Cabled Continental Margin
# 54  RS03ASHS          Cabled Axial Seamount
# 55  RS03AXBS          Cabled Axial Seamount
# 56  RS03AXPD          Cabled Axial Seamount
# 57  RS03AXPS          Cabled Axial Seamount
# 58  RS03CCAL          Cabled Axial Seamount
# 59  RS03ECAL          Cabled Axial Seamount
# 60  RS03INT1          Cabled Axial Seamount
# 61  RS03INT2          Cabled Axial Seamount
# 62  RS05MDPL  Cabled Juan de Fuca Mid-Plate
#
#                                             site_name  \
# 0                      Oregon Inshore Surface Mooring
# 1    Oregon Inshore Surface Piercing Profiler Mooring
# 2      Oregon Shelf Cabled Benthic Experiment Package
# 3                        Oregon Shelf Surface Mooring
# 4      Oregon Shelf Surface Piercing Profiler Mooring
# 5   Oregon Offshore Cabled Benthic Experiment Package
# 6        Oregon Offshore Cabled Deep Profiler Mooring
# 7     Oregon Offshore Cabled Shallow Profiler Mooring
# 8                     Oregon Offshore Surface Mooring
# 10                 Washington Inshore Surface Mooring
# 11  Washington Inshore Surface Piercing Profiler M...
# 12                   Washington Shelf Surface Mooring
# 13  Washington Shelf Surface Piercing Profiler Moo...
# 14               Washington Offshore Profiler Mooring
# 15                Washington Offshore Surface Mooring
# 16                           Central Profiler Mooring
# 17                            Central Surface Mooring
# 18          Central Surface Piercing Profiler Mooring
# 19                   Central Inshore Profiler Mooring
# 20                  Central Offshore Profiler Mooring
# 21                  Upstream Inshore Profiler Mooring
# 22                 Upstream Offshore Profiler Mooring
# 23                           Inshore Profiler Mooring
# 24                            Inshore Surface Mooring
# 25          Inshore Surface Piercing Profiler Mooring
# 26                          Offshore Profiler Mooring
# 27                           Offshore Surface Mooring
# 29                               Apex Surface Mooring
# 30                              Apex Profiler Mooring
# 31                      Flanking Subsurface Mooring A
# 32                      Flanking Subsurface Mooring B
# 34                               Apex Surface Mooring
# 35                              Apex Profiler Mooring
# 36                      Flanking Subsurface Mooring A
# 37                      Flanking Subsurface Mooring B
# 39                              Apex Profiler Mooring
# 40                      Flanking Subsurface Mooring A
# 41                      Flanking Subsurface Mooring B
# 43                               Apex Surface Mooring
# 44                              Apex Profiler Mooring
# 45                      Flanking Subsurface Mooring A
# 46                      Flanking Subsurface Mooring B
# 48            Oregon Slope Base Deep Profiler Mooring
# 49         Oregon Slope Base Shallow Profiler Mooring
# 50               Hydrate Ridge Primary Infrastructure
# 51                         Oregon Slope Base Seafloor
# 52                 Southern Hydrate Summit 1 Seafloor
# 53                 Southern Hydrate Summit 2 Seafloor
# 54                                   ASHES Vent Field
# 55                                Axial Base Seafloor
# 56                   Axial Base Deep Profiler Mooring
# 57                Axial Base Shallow Profiler Mooring
# 58                                    Central Caldera
# 59                                    Eastern Caldera
# 60                International District Vent Field 1
# 61                International District Vent Field 2
# 62                             Primary Infrastructure
#
#                                           description  min_depth  max_depth  \
# 0   A Surface Mooring is a type of mooring that co...          0         25
# 1   A Surface-Piercing Profiler Mooring is a moori...          0         25
# 2   The Benthic Experiment Package (BEP) is a type...         79         79
# 3   A Surface Mooring is a type of mooring that co...          0         80
# 4   A Surface-Piercing Profiler Mooring is a moori...          0         81
# 5   The Benthic Experiment Package (BEP) is a type...        579        579
# 6   Profiler Moorings are a type of mooring that c...        175        576
# 7   Profiler Moorings are a type of mooring that c...         20        588
# 8   A Surface Mooring is a type of mooring that co...          0        588
# 10  A Surface Mooring is a type of mooring that co...          0         29
# 11  A Surface-Piercing Profiler Mooring is a moori...          0         29
# 12  A Surface Mooring is a type of mooring that co...          0         87
# 13  A Surface-Piercing Profiler Mooring is a moori...          0         87
# 14  Profiler Moorings are a type of mooring that c...          0        544
# 15  A Surface Mooring is a type of mooring that co...          0        542
# 16  Profiler Moorings are a type of mooring that c...          0         70
# 17  A Surface Mooring is a type of mooring that co...          0        133
# 18  A Surface-Piercing Profiler Mooring is a moori...          0        133
# 19  Profiler Moorings are a type of mooring that c...          0        127
# 20  Profiler Moorings are a type of mooring that c...          0        148
# 21  Profiler Moorings are a type of mooring that c...          0         95
# 22  Profiler Moorings are a type of mooring that c...          0        452
# 23  Profiler Moorings are a type of mooring that c...          0         70
# 24  A Surface Mooring is a type of mooring that co...          0         92
# 25  A Surface-Piercing Profiler Mooring is a moori...          0         92
# 26  Profiler Moorings are a type of mooring that c...          0        453
# 27  A Surface Mooring is a type of mooring that co...          0        450
# 29  A Surface Mooring is a type of mooring that co...          0       5200
# 30  Profiler Moorings are a type of mooring that c...        150       5200
# 31  Flanking Subsurface Moorings are located at gl...         30       5200
# 32  Flanking Subsurface Moorings are located at gl...         30       5200
# 34  A Surface Mooring is a type of mooring that co...          0       2800
# 35  Profiler Moorings are a type of mooring that c...        150       2800
# 36  Flanking Subsurface Moorings are located at gl...         30       2800
# 37  Flanking Subsurface Moorings are located at gl...         30       2800
# 39  Profiler Moorings are a type of mooring that c...        150       4219
# 40  Flanking Subsurface Moorings are located at gl...         30       4126
# 41  Flanking Subsurface Moorings are located at gl...         30       4145
# 43  A Surface Mooring is a type of mooring that co...          0       4800
# 44  Profiler Moorings are a type of mooring that c...        150       4800
# 45  Flanking Subsurface Moorings are located at gl...         30       4800
# 46  Flanking Subsurface Moorings are located at gl...         30       4800
# 48  Profiler Moorings are a type of mooring that c...        150       2893
# 49  Profiler Moorings are a type of mooring that c...          5       2906
# 50  Primary Nodes are connected to the land-based ...       1241       1241
# 51  A Junction Box (JBox) rests on the seafloor an...       2901       2901
# 52  A Junction Box (JBox) rests on the seafloor an...        775        775
# 53  A Junction Box (JBox) rests on the seafloor an...        772        772
# 54  A Junction Box (JBox) rests on the seafloor an...       1552       1552
# 55  A Junction Box (JBox) rests on the seafloor an...       2611       2611
# 56  Profiler Moorings are a type of mooring that c...        150       2604
# 57  Profiler Moorings are a type of mooring that c...          5       2607
# 58  A Junction Box (JBox) rests on the seafloor an...       1523       1523
# 59  A Junction Box (JBox) rests on the seafloor an...       1519       1519
# 60  A Junction Box (JBox) rests on the seafloor an...       1516       1516
# 61  A Junction Box (JBox) rests on the seafloor an...       1526       1526
# 62  Primary Nodes are connected to the land-based ...       2820       2820
#
#     longitude  latitude
# 0   -124.0950   44.6598
# 1   -124.0960   44.6620
# 2   -124.3060   44.6371
# 3   -124.3040   44.6393
# 4   -124.2990   44.6372
# 5   -124.9540   44.3695
# 6   -124.9530   44.3683
# 7   -124.9560   44.3741
# 8   -124.9560   44.3811
# 10  -124.2720   47.1336
# 11  -124.2690   47.1360
# 12  -124.5660   46.9859
# 13  -124.5650   46.9843
# 14  -124.9820   46.8517
# 15  -124.9720   46.8508
# 16   -70.7795   40.1392
# 17   -70.7785   40.1334
# 18   -70.7701   40.1341
# 19   -70.8782   40.2267
# 20   -70.8789   40.0963
# 21   -70.7700   40.3649
# 22   -70.7708   39.9394
# 23   -70.8882   40.3647
# 24   -70.8783   40.3619
# 25   -70.8818   40.3672
# 26   -70.8802   39.9365
# 27   -70.8870   39.9371
# 29   -42.4409  -42.9204
# 30   -42.4957  -42.9781
# 31   -42.8802  -42.4921
# 32   -42.1255  -42.4960
# 34   -39.4673   59.9341
# 35   -39.4886   59.9695
# 36   -39.8412   59.8177
# 37   -39.3148   59.7155
# 39  -144.8060   50.0796
# 40  -144.2400   49.9743
# 41  -144.3980   50.3293
# 43   -89.3567  -54.4076
# 44   -89.3191  -54.4693
# 45   -89.6542  -54.1042
# 46   -88.9318  -54.0803
# 48  -125.3806   44.5274
# 49  -125.3893   44.5290
# 50  -125.1483   44.4815
# 51  -125.3898   44.5153
# 52  -125.1481   44.5691
# 53  -125.1468   44.5699
# 54  -130.0139   45.9337
# 55  -129.7543   45.8168
# 56  -129.7590   45.8297
# 57  -129.7535   45.8305
# 58  -130.0089   45.9549
# 59  -129.9742   45.9399
# 60  -129.9789   45.9263
# 61  -129.9778   45.9258
# 62  -127.2784   45.7556

# %%
ooi.instruments
# Out:
#                                    array_name  \
# 0        Cabled Axial Seamount (Cabled Array)
# 1        Cabled Axial Seamount (Cabled Array)
# 2        Cabled Axial Seamount (Cabled Array)
# 3        Cabled Axial Seamount (Cabled Array)
# 4        Cabled Axial Seamount (Cabled Array)
# ..                                        ...
# 111  Cabled Continental Margin (Cabled Array)
# 112  Cabled Continental Margin (Cabled Array)
# 113  Cabled Continental Margin (Cabled Array)
# 114  Cabled Continental Margin (Cabled Array)
# 115  Cabled Continental Margin (Cabled Array)
#
#                                       site_name        infrastructure_name  \
# 0                              ASHES Vent Field  Medium-Power JBox (MJ03B)
# 1                              ASHES Vent Field  Medium-Power JBox (MJ03B)
# 2                              ASHES Vent Field  Medium-Power JBox (MJ03B)
# 3                              ASHES Vent Field  Medium-Power JBox (MJ03B)
# 4                              ASHES Vent Field  Medium-Power JBox (MJ03B)
# ..                                          ...                        ...
# 111  Oregon Slope Base Shallow Profiler Mooring   Shallow Profiler (SF01A)
# 112          Southern Hydrate Summit 1 Seafloor     Low-Power JBox (LJ01B)
# 113          Southern Hydrate Summit 1 Seafloor     Low-Power JBox (LJ01B)
# 114          Southern Hydrate Summit 2 Seafloor  Medium-Power JBox (MJ01B)
# 115          Southern Hydrate Summit 2 Seafloor  Medium-Power JBox (MJ01B)
#
#                      instrument_name stream_method                 stream_rd
# 0           Bottom Pressure and Tilt      streamed         botpt_lily_sample
# 1           Bottom Pressure and Tilt      streamed         botpt_iris_sample
# 2           Bottom Pressure and Tilt      streamed     botpt_nano_sample_15s
# 3           Bottom Pressure and Tilt      streamed         botpt_nano_sample
# 4           Bottom Pressure and Tilt      streamed    botpt_nano_sample_24hr
# ..                               ...           ...                       ...
# 111                       pCO2 Water      streamed  pco2w_a_sami_data_record
# 112  3-D Single Point Velocity Meter      streamed            vel3d_b_sample
# 113          Tidal Seafloor Pressure      streamed           prest_real_time
# 114       Velocity Profiler (75 kHz)      streamed      adcp_pd0_beam_parsed
# 115       Velocity Profiler (75 kHz)      streamed        adcp_velocity_beam
#
# [116 rows x 6 columns]

# %%
# Reprising an earlier cell let's go for CTD data (don't re-run this first line (kilroy) because that was done earlier)
ooi = OOI()
ooi.search(region='cabled', site='axial base shallow profiler', node='shallow profiler', instrument='CTD')
ooi.instruments                    # an attribute
ooi.data_availability()
# Out:
# (MainThread) Please wait while we fetch the metadata ...
#   RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample
# 0               Cabled Axial Seamount (Cabled Array)
# 1                Axial Base Shallow Profiler Mooring
# 2                           Shallow Profiler (SF03A)
# 3                                                CTD
# 4                                           streamed
# 5                                 ctdpf_sbe43_sample

# %%
begin_date = '2018-01-01'
end_date = '2018-01-02'
ooi.request_data(begin_date=begin_date, end_date=end_date)
# Out:
# <Data Source: OOI (1 Instrument Stream)>

# %%
# Once the data order is complete we need a way of placing the URL in the ooi object so we do not have
#   to repeat the query. That goes into the yodapy README also. Are you tired of re-running this cell? 
#   Just run ooi.to_xarray() and it will do the polling for you. 
ooi.check_status()
# Out:
# (MainThread) Request (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T220916352Z-RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample) completed.
# Request (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T220916352Z-RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample) completed.
# ['https://opendap.oceanobservatories.org/thredds/catalog/ooi/rob5@uw.edu/20191114T220916352Z-RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample/catalog.html']

# %%
ds = ooi.to_xarray()
# Out:
# (MainThread) Request (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T220916352Z-RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample) completed.
# Request (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T220916352Z-RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample) completed.
# (MainThread) Acquiring data from opendap urls ...
# /srv/conda/envs/notebook/lib/python3.7/site-packages/yodapy/utils/conn.py:159: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   return xr.open_mfdataset(filt_ds, engine="netcdf4", **kwargs)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/api.py:931: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,

# %%
ds[0]
# Out:
# <xarray.Dataset>
# Dimensions:                                 (obs: 86398)
# Coordinates:
#   * obs                                     (obs) int32 0 1 2 ... 86396 86397
#     time                                    (obs) datetime64[ns] dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_pressure                       (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     lat                                     (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     lon                                     (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
# Data variables:
#     deployment                              (obs) int32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     id                                      (obs) |S64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     conductivity                            (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     driver_timestamp                        (obs) datetime64[ns] dask.array<chunksize=(86398,), meta=np.ndarray>
#     ext_volt0                               (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     ingestion_timestamp                     (obs) datetime64[ns] dask.array<chunksize=(86398,), meta=np.ndarray>
#     internal_timestamp                      (obs) datetime64[ns] dask.array<chunksize=(86398,), meta=np.ndarray>
#     port_timestamp                          (obs) datetime64[ns] dask.array<chunksize=(86398,), meta=np.ndarray>
#     preferred_timestamp                     (obs) object dask.array<chunksize=(86398,), meta=np.ndarray>
#     pressure                                (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     pressure_temp                           (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     temperature                             (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_temperature                    (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_conductivity                   (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     practical_salinity                      (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     corrected_dissolved_oxygen              (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     density                                 (obs) float64 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_temperature_qc_executed        (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_temperature_qc_results         (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_pressure_qc_executed           (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_pressure_qc_results            (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_conductivity_qc_executed       (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     seawater_conductivity_qc_results        (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     corrected_dissolved_oxygen_qc_executed  (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     corrected_dissolved_oxygen_qc_results   (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     density_qc_executed                     (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     density_qc_results                      (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     practical_salinity_qc_executed          (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
#     practical_salinity_qc_results           (obs) float32 dask.array<chunksize=(86398,), meta=np.ndarray>
# Attributes:
#     _NCProperties:                   version=1|netcdflibversion=4.6.1|hdf5lib...
#     node:                            SF03A
#     comment:
#     publisher_email:
#     sourceUrl:                       http://oceanobservatories.org/
#     collection_method:               streamed
#     stream:                          ctdpf_sbe43_sample
#     featureType:                     point
#     creator_email:
#     publisher_name:                  Ocean Observatories Initiative
#     date_modified:                   2019-11-14T22:13:30.932610
#     keywords:
#     cdm_data_type:                   Point
#     references:                      More information can be found at http://...
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     date_created:                    2019-11-14T22:13:30.932608
#     id:                              RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctd...
#     requestUUID:                     08da15e5-707d-416b-8a21-dc711625ec5f
#     contributor_role:
#     summary:                         Dataset Generated by Stream Engine from ...
#     keywords_vocabulary:
#     institution:                     Ocean Observatories Initiative
#     naming_authority:                org.oceanobservatories
#     feature_Type:                    point
#     infoUrl:                         http://oceanobservatories.org/
#     license:
#     contributor_name:
#     uuid:                            08da15e5-707d-416b-8a21-dc711625ec5f
#     creator_name:                    Ocean Observatories Initiative
#     title:                           Data produced by Stream Engine version 1...
#     sensor:                          2A-CTDPFA302
#     standard_name_vocabulary:        NetCDF Climate and Forecast (CF) Metadat...
#     acknowledgement:
#     Conventions:                     CF-1.6
#     project:                         Ocean Observatories Initiative
#     source:                          RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctd...
#     publisher_url:                   http://oceanobservatories.org/
#     creator_url:                     http://oceanobservatories.org/
#     nodc_template_version:           NODC_NetCDF_TimeSeries_Orthogonal_Templa...
#     subsite:                         RS03AXPS
#     processing_level:                L2
#     history:                         2019-11-14T22:13:30.932576 generated fro...
#     time_coverage_start:             2018-01-01T00:00:00.983558
#     time_coverage_end:               2018-01-01T23:59:59.999175
#     time_coverage_resolution:        P1.00S
#     geospatial_lat_min:              45.83049
#     geospatial_lat_max:              45.83049
#     geospatial_lat_units:            degrees_north
#     geospatial_lat_resolution:       0.1
#     geospatial_lon_min:              -129.75326
#     geospatial_lon_max:              -129.75326
#     geospatial_lon_units:            degrees_east
#     geospatial_lon_resolution:       0.1
#     geospatial_vertical_units:       meters
#     geospatial_vertical_resolution:  0.1
#     geospatial_vertical_positive:    down
#     DODS.strlen:                     14
#     DODS.dimName:                    string14
#     DODS_EXTRA.Unlimited_Dimension:  obs

# %%
# This will not work because OOI data are not CF-compliant in format
# ds[0].to_netcdf('fubar.nc')

# This will reach into the OOI system (not the CAVA system) and download and save NetCDF content
filenamelist = ooi.download_netcdfs()
# Out:
# (MainThread) Downloading netcdfs ...
# (MainThread) Downloading deployment0004_RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample_20180101T000000.983558-20180101T235959.999175.nc...
# (MainThread) Writing deployment0004_RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample_20180101T000000.983558-20180101T235959.999175.nc...
# (MainThread) deployment0004_RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample_20180101T000000.983558-20180101T235959.999175.nc successfully downloaded ---
# (MainThread) --- Checking deployment0004_RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample_20180101T000000.983558-20180101T235959.999175.nc ---
# (MainThread) --- Checks passed for deployment0004_RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctdpf_sbe43_sample_20180101T000000.983558-20180101T235959.999175.nc ---

# %%
print(len(filenamelist))
# Out:
# 1

# %%
import xarray as xr
ooids = xr.open_dataset(filenamelist[0])              # or use open_mfdataset(filenamelist) but this can conflate types of data

# %%
ooids
# Out:
# <xarray.Dataset>
# Dimensions:                                 (obs: 86398)
# Coordinates:
#   * obs                                     (obs) int32 0 1 2 ... 86396 86397
#     time                                    (obs) datetime64[ns] ...
#     seawater_pressure                       (obs) float64 ...
#     lat                                     (obs) float64 ...
#     lon                                     (obs) float64 ...
# Data variables:
#     deployment                              (obs) int32 ...
#     id                                      (obs) |S36 ...
#     conductivity                            (obs) float64 ...
#     driver_timestamp                        (obs) datetime64[ns] ...
#     ext_volt0                               (obs) float64 ...
#     ingestion_timestamp                     (obs) datetime64[ns] ...
#     internal_timestamp                      (obs) datetime64[ns] ...
#     port_timestamp                          (obs) datetime64[ns] ...
#     preferred_timestamp                     (obs) object ...
#     pressure                                (obs) float64 ...
#     pressure_temp                           (obs) float64 ...
#     temperature                             (obs) float64 ...
#     seawater_temperature                    (obs) float64 ...
#     seawater_conductivity                   (obs) float64 ...
#     practical_salinity                      (obs) float64 ...
#     corrected_dissolved_oxygen              (obs) float64 ...
#     density                                 (obs) float64 ...
#     seawater_temperature_qc_executed        (obs) uint8 ...
#     seawater_temperature_qc_results         (obs) uint8 ...
#     seawater_pressure_qc_executed           (obs) uint8 ...
#     seawater_pressure_qc_results            (obs) uint8 ...
#     seawater_conductivity_qc_executed       (obs) uint8 ...
#     seawater_conductivity_qc_results        (obs) uint8 ...
#     corrected_dissolved_oxygen_qc_executed  (obs) uint8 ...
#     corrected_dissolved_oxygen_qc_results   (obs) uint8 ...
#     density_qc_executed                     (obs) uint8 ...
#     density_qc_results                      (obs) uint8 ...
#     practical_salinity_qc_executed          (obs) uint8 ...
#     practical_salinity_qc_results           (obs) uint8 ...
# Attributes:
#     node:                            SF03A
#     comment:
#     publisher_email:
#     sourceUrl:                       http://oceanobservatories.org/
#     collection_method:               streamed
#     stream:                          ctdpf_sbe43_sample
#     featureType:                     point
#     creator_email:
#     publisher_name:                  Ocean Observatories Initiative
#     date_modified:                   2019-11-14T22:13:30.932610
#     keywords:
#     cdm_data_type:                   Point
#     references:                      More information can be found at http://...
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     date_created:                    2019-11-14T22:13:30.932608
#     id:                              RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctd...
#     requestUUID:                     08da15e5-707d-416b-8a21-dc711625ec5f
#     contributor_role:
#     summary:                         Dataset Generated by Stream Engine from ...
#     keywords_vocabulary:
#     institution:                     Ocean Observatories Initiative
#     naming_authority:                org.oceanobservatories
#     feature_Type:                    point
#     infoUrl:                         http://oceanobservatories.org/
#     license:
#     contributor_name:
#     uuid:                            08da15e5-707d-416b-8a21-dc711625ec5f
#     creator_name:                    Ocean Observatories Initiative
#     title:                           Data produced by Stream Engine version 1...
#     sensor:                          2A-CTDPFA302
#     standard_name_vocabulary:        NetCDF Climate and Forecast (CF) Metadat...
#     acknowledgement:
#     Conventions:                     CF-1.6
#     project:                         Ocean Observatories Initiative
#     source:                          RS03AXPS-SF03A-2A-CTDPFA302-streamed-ctd...
#     publisher_url:                   http://oceanobservatories.org/
#     creator_url:                     http://oceanobservatories.org/
#     nodc_template_version:           NODC_NetCDF_TimeSeries_Orthogonal_Templa...
#     subsite:                         RS03AXPS
#     processing_level:                L2
#     history:                         2019-11-14T22:13:30.932576 generated fro...
#     time_coverage_start:             2018-01-01T00:00:00.983558
#     time_coverage_end:               2018-01-01T23:59:59.999175
#     time_coverage_resolution:        P1.00S
#     geospatial_lat_min:              45.83049
#     geospatial_lat_max:              45.83049
#     geospatial_lat_units:            degrees_north
#     geospatial_lat_resolution:       0.1
#     geospatial_lon_min:              -129.75326
#     geospatial_lon_max:              -129.75326
#     geospatial_lon_units:            degrees_east
#     geospatial_lon_resolution:       0.1
#     geospatial_vertical_units:       meters
#     geospatial_vertical_resolution:  0.1
#     geospatial_vertical_positive:    down

# %%
# re-do the search specific to chlorophyll: Notice the instruments value is a search term
ooi.search(region='cabled', instrument='fluorometer')
ooi.instruments                    # an attribute
ooi.data_availability()

# to reset the filters use ooi.clear() to avoid sub-filtering filtered results to arrive at nothing!

# The following table lists possible instruments as *column headers* and these are transposed in the subsequent data availability
#   graph into rows for the time series.
# Out:
#   RS01SBPD-DP01A-03-FLCDRA102-recovered_inst-dpc_flcdrtd_instrument_recovered  \
# 0           Cabled Continental Margin (Cabled Array)
# 1            Oregon Slope Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP01A)
# 3                                   CDOM Fluorometer
# 4                                     recovered_inst
# 5                   dpc_flcdrtd_instrument_recovered
#
#   RS01SBPD-DP01A-03-FLCDRA102-recovered_wfp-dpc_flcdrtd_instrument_recovered  \
# 0           Cabled Continental Margin (Cabled Array)
# 1            Oregon Slope Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP01A)
# 3                                   CDOM Fluorometer
# 4                                      recovered_wfp
# 5                   dpc_flcdrtd_instrument_recovered
#
#   RS03AXPD-DP03A-03-FLCDRA302-recovered_inst-dpc_flcdrtd_instrument_recovered  \
# 0               Cabled Axial Seamount (Cabled Array)
# 1                   Axial Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP03A)
# 3                                   CDOM Fluorometer
# 4                                     recovered_inst
# 5                   dpc_flcdrtd_instrument_recovered
#
#   RS03AXPD-DP03A-03-FLCDRA302-recovered_wfp-dpc_flcdrtd_instrument_recovered  \
# 0               Cabled Axial Seamount (Cabled Array)
# 1                   Axial Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP03A)
# 3                                   CDOM Fluorometer
# 4                                      recovered_wfp
# 5                   dpc_flcdrtd_instrument_recovered
#
#   RS01SBPD-DP01A-04-FLNTUA102-recovered_inst-dpc_flnturtd_instrument_recovered  \
# 0           Cabled Continental Margin (Cabled Array)
# 1            Oregon Slope Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP01A)
# 3                           2-Wavelength Fluorometer
# 4                                     recovered_inst
# 5                  dpc_flnturtd_instrument_recovered
#
#   RS01SBPD-DP01A-04-FLNTUA102-recovered_wfp-dpc_flnturtd_instrument_recovered  \
# 0           Cabled Continental Margin (Cabled Array)
# 1            Oregon Slope Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP01A)
# 3                           2-Wavelength Fluorometer
# 4                                      recovered_wfp
# 5                  dpc_flnturtd_instrument_recovered
#
#   RS03AXPD-DP03A-03-FLNTUA302-recovered_inst-dpc_flnturtd_instrument_recovered  \
# 0               Cabled Axial Seamount (Cabled Array)
# 1                   Axial Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP03A)
# 3                           2-Wavelength Fluorometer
# 4                                     recovered_inst
# 5                  dpc_flnturtd_instrument_recovered
#
#   RS03AXPD-DP03A-03-FLNTUA302-recovered_wfp-dpc_flnturtd_instrument_recovered  \
# 0               Cabled Axial Seamount (Cabled Array)
# 1                   Axial Base Deep Profiler Mooring
# 2                    Wire-Following Profiler (DP03A)
# 3                           2-Wavelength Fluorometer
# 4                                      recovered_wfp
# 5                  dpc_flnturtd_instrument_recovered
#
#   RS01SBPS-PC01A-4C-FLORDD103-streamed-flort_d_data_record  \
# 0           Cabled Continental Margin (Cabled Array)
# 1         Oregon Slope Base Shallow Profiler Mooring
# 2                              200m Platform (PC01A)
# 3                           2-Wavelength Fluorometer
# 4                                           streamed
# 5                                flort_d_data_record
#
#   RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record  \
# 0           Cabled Continental Margin (Cabled Array)
# 1         Oregon Slope Base Shallow Profiler Mooring
# 2                           Shallow Profiler (SF01A)
# 3                           3-Wavelength Fluorometer
# 4                                           streamed
# 5                                flort_d_data_record
#
#   RS03AXPS-PC03A-4C-FLORDD303-streamed-flort_d_data_record  \
# 0               Cabled Axial Seamount (Cabled Array)
# 1                Axial Base Shallow Profiler Mooring
# 2                              200m Platform (PC03A)
# 3                           2-Wavelength Fluorometer
# 4                                           streamed
# 5                                flort_d_data_record
#
#   RS03AXPS-SF03A-3A-FLORTD301-streamed-flort_d_data_record
# 0               Cabled Axial Seamount (Cabled Array)
# 1                Axial Base Shallow Profiler Mooring
# 2                           Shallow Profiler (SF03A)
# 3                           3-Wavelength Fluorometer
# 4                                           streamed
# 5                                flort_d_data_record

# %%
# Let's be specific to the Oregon Slope Base profiler
ooi.search(region='cabled', site = 'Oregon Slope Base', node = 'Shallow Profiler', instrument='fluorometer', )
ooi.instruments                    # an attribute
ooi.data_availability()
# Out:
#   RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record
# 0           Cabled Continental Margin (Cabled Array)
# 1         Oregon Slope Base Shallow Profiler Mooring
# 2                           Shallow Profiler (SF01A)
# 3                           3-Wavelength Fluorometer
# 4                                           streamed
# 5                                flort_d_data_record

# %%
begin_date = '2019-06-01'
end_date = '2019-09-30'
ooi.request_data(begin_date=begin_date, end_date=end_date, time_check = False)
# Out:
# <Data Source: OOI (1 Instrument Stream)>

# %%
chlords = ooi.to_xarray()
# Out:
# (MainThread) Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# (MainThread) Data request time elapsed: 10s
# Data request time elapsed: 10s
# (MainThread) Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# (MainThread) Data request time elapsed: 20s
# Data request time elapsed: 20s
# (MainThread) Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# (MainThread) Data request time elapsed: 30s
# Data request time elapsed: 30s
# (MainThread) Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# (MainThread) Data request time elapsed: 41s
# Data request time elapsed: 41s
# (MainThread) Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# (MainThread) Data request time elapsed: 51s
# Data request time elapsed: 51s
# (MainThread) Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# (MainThread) Data request time elapsed: 61s
# Data request time elapsed: 61s
# (MainThread) Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# Your data (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) is still compiling... Please wait.
# (MainThread) Data request time elapsed: 72s
# Data request time elapsed: 72s
# (MainThread) Request (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) completed.
# Request (https://opendap.oceanobservatories.org/async_results/rob5@uw.edu/20191114T223806102Z-RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record) completed.
# (MainThread) Acquiring data from opendap urls ...
# /srv/conda/envs/notebook/lib/python3.7/site-packages/yodapy/utils/conn.py:159: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   return xr.open_mfdataset(filt_ds, engine="netcdf4", **kwargs)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/api.py:931: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,

# %%
filenamelist = ooi.download_netcdfs()

# %%
chlor = xr.open_mfdataset(filenamelist)
chlor
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   """Entry point for launching an IPython kernel.
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/api.py:931: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# <xarray.Dataset>
# Dimensions:                                          (obs: 8121274)
# Coordinates:
#   * obs                                              (obs) int64 0 1 ... 775202
#     time                                             (obs) datetime64[ns] dask.array<chunksize=(951585,), meta=np.ndarray>
#     int_ctd_pressure                                 (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     lat                                              (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     lon                                              (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
# Data variables:
#     deployment                                       (obs) int32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     id                                               (obs) |S36 dask.array<chunksize=(951585,), meta=np.ndarray>
#     date_string                                      (obs) object dask.array<chunksize=(951585,), meta=np.ndarray>
#     driver_timestamp                                 (obs) datetime64[ns] dask.array<chunksize=(951585,), meta=np.ndarray>
#     ingestion_timestamp                              (obs) datetime64[ns] dask.array<chunksize=(951585,), meta=np.ndarray>
#     internal_timestamp                               (obs) datetime64[ns] dask.array<chunksize=(951585,), meta=np.ndarray>
#     measurement_wavelength_beta                      (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     measurement_wavelength_cdom                      (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     measurement_wavelength_chl                       (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     port_timestamp                                   (obs) datetime64[ns] dask.array<chunksize=(951585,), meta=np.ndarray>
#     preferred_timestamp                              (obs) object dask.array<chunksize=(951585,), meta=np.ndarray>
#     raw_internal_temp                                (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     raw_signal_beta                                  (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     raw_signal_cdom                                  (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     raw_signal_chl                                   (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     signal_1_offset                                  (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     signal_1_scale_factor                            (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     signal_2_offset                                  (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     signal_2_scale_factor                            (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     signal_3_offset                                  (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     signal_3_scale_factor                            (obs) float32 dask.array<chunksize=(951585,), meta=np.ndarray>
#     time_string                                      (obs) object dask.array<chunksize=(951585,), meta=np.ndarray>
#     fluorometric_chlorophyll_a                       (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     fluorometric_cdom                                (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     total_volume_scattering_coefficient              (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     seawater_temperature                             (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     practical_salinity                               (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     seawater_scattering_coefficient                  (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     optical_backscatter                              (obs) float64 dask.array<chunksize=(951585,), meta=np.ndarray>
#     fluorometric_chlorophyll_a_qc_executed           (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
#     fluorometric_chlorophyll_a_qc_results            (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
#     fluorometric_cdom_qc_executed                    (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
#     fluorometric_cdom_qc_results                     (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
#     total_volume_scattering_coefficient_qc_executed  (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
#     total_volume_scattering_coefficient_qc_results   (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
#     optical_backscatter_qc_executed                  (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
#     optical_backscatter_qc_results                   (obs) uint8 dask.array<chunksize=(951585,), meta=np.ndarray>
# Attributes:
#     node:                            SF01A
#     comment:
#     publisher_email:
#     sourceUrl:                       http://oceanobservatories.org/
#     collection_method:               streamed
#     stream:                          flort_d_data_record
#     featureType:                     point
#     creator_email:
#     publisher_name:                  Ocean Observatories Initiative
#     date_modified:                   2019-11-14T22:39:00.797580
#     keywords:
#     cdm_data_type:                   Point
#     references:                      More information can be found at http://...
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     date_created:                    2019-11-14T22:39:00.797574
#     id:                              RS01SBPS-SF01A-3A-FLORTD101-streamed-flo...
#     requestUUID:                     f7d63a95-235e-4ecb-b437-0bc56ae6a166
#     contributor_role:
#     summary:                         Dataset Generated by Stream Engine from ...
#     keywords_vocabulary:
#     institution:                     Ocean Observatories Initiative
#     naming_authority:                org.oceanobservatories
#     feature_Type:                    point
#     infoUrl:                         http://oceanobservatories.org/
#     license:
#     contributor_name:
#     uuid:                            f7d63a95-235e-4ecb-b437-0bc56ae6a166
#     creator_name:                    Ocean Observatories Initiative
#     title:                           Data produced by Stream Engine version 1...
#     sensor:                          3A-FLORTD101
#     standard_name_vocabulary:        NetCDF Climate and Forecast (CF) Metadat...
#     acknowledgement:
#     Conventions:                     CF-1.6
#     project:                         Ocean Observatories Initiative
#     source:                          RS01SBPS-SF01A-3A-FLORTD101-streamed-flo...
#     publisher_url:                   http://oceanobservatories.org/
#     creator_url:                     http://oceanobservatories.org/
#     nodc_template_version:           NODC_NetCDF_TimeSeries_Orthogonal_Templa...
#     subsite:                         RS01SBPS
#     processing_level:                L2
#     history:                         2019-11-14T22:39:00.797497 generated fro...
#     time_coverage_start:             2019-06-01T00:00:00.339009
#     time_coverage_end:               2019-06-14T05:12:41.816166
#     time_coverage_resolution:        P1.20S
#     geospatial_lat_min:              44.52897
#     geospatial_lat_max:              44.52897
#     geospatial_lat_units:            degrees_north
#     geospatial_lat_resolution:       0.1
#     geospatial_lon_min:              -125.38966
#     geospatial_lon_max:              -125.38966
#     geospatial_lon_units:            degrees_east
#     geospatial_lon_resolution:       0.1
#     geospatial_vertical_units:       meters
#     geospatial_vertical_resolution:  0.1
#     geospatial_vertical_positive:    down

# %%
# how many results came back? Remember OOI might chop up the data into contiguous time segments arbitrarily
len(filenamelist)
# Out:
# 3

# %%
chlor = chlor.swap_dims({'obs':'time'})
chlor.fluorometric_chlorophyll_a.plot()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Looking ahead; we need zarr...
# !pip install zarr
# Out:
# Collecting zarr
#   Downloading https://files.pythonhosted.org/packages/d0/d0/02a3457f4e86a8f74104e7686c43b6bf0c76534b626f174eb20786a6f781/zarr-2.3.2.tar.gz (3.3MB)
#      |████████████████████████████████| 3.3MB 5.3MB/s eta 0:00:01
# Collecting asciitree (from zarr)
#   Downloading https://files.pythonhosted.org/packages/2d/6a/885bc91484e1aa8f618f6f0228d76d0e67000b0fdd6090673b777e311913/asciitree-0.3.3.tar.gz
# Requirement already satisfied: numpy>=1.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from zarr) (1.17.2)
# Collecting fasteners (from zarr)
#   Downloading https://files.pythonhosted.org/packages/18/bd/55eb2d6397b9c0e263af9d091ebdb756b15756029b3cededf6461481bc63/fasteners-0.15-py2.py3-none-any.whl
# Collecting numcodecs>=0.6.2 (from zarr)
#   Downloading https://files.pythonhosted.org/packages/53/2a/1dc435cbd1d082827190a3e46168fd04f74e266e91313969d5a1aab601bf/numcodecs-0.6.4.tar.gz (3.8MB)
#      |████████████████████████████████| 3.8MB 43.5MB/s eta 0:00:01
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fasteners->zarr) (1.12.0)
# Collecting monotonic>=0.1 (from fasteners->zarr)
#   Downloading https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
# Building wheels for collected packages: zarr, asciitree, numcodecs
#   Building wheel for zarr (setup.py) ... done
#   Created wheel for zarr: filename=zarr-2.3.2-cp37-none-any.whl size=127448 sha256=f4aca629052e9ffde5812980e5501fc2c48d74df441818c0fb883112d66ebe7f
#   Stored in directory: /home/jovyan/.cache/pip/wheels/8d/6c/4b/82a896c388f0602858cabeb682acbdbb4f2254d44e570fd0cb
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-cp37-none-any.whl size=5036 sha256=a457bd8755ffa5a47595308bdd7883f7e7741d063774a98d5b2d85145435b93c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/1d/d9/58/9808b306744df0208fccc640d3d9952a5bc7468502d42897d5
#   Building wheel for numcodecs (setup.py) ... done
#   Created wheel for numcodecs: filename=numcodecs-0.6.4-cp37-cp37m-linux_x86_64.whl size=4750843 sha256=9c263cd58b07ac275f1464f7bf020731766e02244c93421d67ed7ca94b5f29d2
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ca/07/ed/fea2e120cbb91d90b577c5ac56b4b082024f56fcd88e9afa55
# Successfully built zarr asciitree numcodecs
# Installing collected packages: asciitree, monotonic, fasteners, numcodecs, zarr
# Successfully installed asciitree-0.3.3 fasteners-0.15 monotonic-1.5 numcodecs-0.6.4 zarr-2.3.2

# %%
# If this cell fails because you need zarr and it is not installed: See previous cell
# Looking ahead to zarr
import s3fs

cavapath = 'io2data-test/data/RS01SBPS-SF01A-3A-FLORTD101-streamed-flort_d_data_record'
FS = s3fs.S3FileSystem(anon=True)        # because not using an AWS cred
s3ds = xr.open_zarr(store=s3fs.S3Map(cavapath, s3=FS), consolidated=True)

# %%
s3ds
# Out:
# <xarray.Dataset>
# Dimensions:                                          (time: 97705446)
# Coordinates:
#     int_ctd_pressure                                 (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     lat                                              (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     lon                                              (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#   * time                                             (time) datetime64[ns] 2014-10-06T14:10:13 ... 2019-09-27T18:41:51.008452096
# Data variables:
#     date_string                                      (time) <U1 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     deployment                                       (time) int32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     driver_timestamp                                 (time) datetime64[ns] dask.array<chunksize=(1048576,), meta=np.ndarray>
#     fluorometric_cdom                                (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     fluorometric_cdom_qc_executed                    (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     fluorometric_cdom_qc_results                     (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     fluorometric_chlorophyll_a                       (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     fluorometric_chlorophyll_a_qc_executed           (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     fluorometric_chlorophyll_a_qc_results            (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     id                                               (time) <U36 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     ingestion_timestamp                              (time) datetime64[ns] dask.array<chunksize=(1048576,), meta=np.ndarray>
#     internal_timestamp                               (time) datetime64[ns] dask.array<chunksize=(1048576,), meta=np.ndarray>
#     measurement_wavelength_beta                      (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     measurement_wavelength_cdom                      (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     measurement_wavelength_chl                       (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     optical_backscatter                              (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     optical_backscatter_qc_executed                  (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     optical_backscatter_qc_results                   (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     port_timestamp                                   (time) datetime64[ns] dask.array<chunksize=(1048576,), meta=np.ndarray>
#     practical_salinity                               (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     preferred_timestamp                              (time) <U36 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     raw_internal_temp                                (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     raw_signal_beta                                  (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     raw_signal_cdom                                  (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     raw_signal_chl                                   (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     seawater_scattering_coefficient                  (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     seawater_temperature                             (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     signal_1_offset                                  (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     signal_1_scale_factor                            (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     signal_2_offset                                  (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     signal_2_scale_factor                            (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     signal_3_offset                                  (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     signal_3_scale_factor                            (time) float32 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     time_string                                      (time) <U1 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     total_volume_scattering_coefficient              (time) float64 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     total_volume_scattering_coefficient_qc_executed  (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
#     total_volume_scattering_coefficient_qc_results   (time) uint8 dask.array<chunksize=(1048576,), meta=np.ndarray>
# Attributes:
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     Notes:                           This netCDF product is a copy of the dat...
#     Owner:                           University of Washington Cabled Array Va...
#     acknowledgement:
#     cdm_data_type:                   Point
#     collection_method:               streamed
#     comment:                         Some of the metadata of this dataset has...
#     contributor_name:
#     contributor_role:
#     creator_email:
#     creator_name:                    Ocean Observatories Initiative
#     creator_url:                     http://oceanobservatories.org/
#     date_created:                    2019-11-12T23:42:08.675553
#     date_downloaded:                 2019-11-13T00:17:23.136299
#     date_modified:                   2019-11-12T23:42:08.675558
#     date_processed:                  2019-11-13T00:21:57.400125
#     featureType:                     point
#     feature_Type:                    point
#     geospatial_lat_max:              44.52897
#     geospatial_lat_min:              44.52897
#     geospatial_lat_resolution:       0.1
#     geospatial_lat_units:            degrees_north
#     geospatial_lon_max:              -125.38937
#     geospatial_lon_min:              -125.38937
#     geospatial_lon_resolution:       0.1
#     geospatial_lon_units:            degrees_east
#     geospatial_vertical_positive:    down
#     geospatial_vertical_resolution:  0.1
#     geospatial_vertical_units:       meters
#     history:                         2019-11-12T23:42:08.675491 generated fro...
#     id:                              RS01SBPS-SF01A-3A-FLORTD101-streamed-flo...
#     infoUrl:                         http://oceanobservatories.org/
#     institution:                     Ocean Observatories Initiative
#     keywords:
#     keywords_vocabulary:
#     license:
#     naming_authority:                org.oceanobservatories
#     nodc_template_version:           NODC_NetCDF_TimeSeries_Orthogonal_Templa...
#     node:                            SF01A
#     processing_level:                L2
#     project:                         Ocean Observatories Initiative
#     publisher_email:
#     publisher_name:                  Ocean Observatories Initiative
#     publisher_url:                   http://oceanobservatories.org/
#     references:                      More information can be found at http://...
#     requestUUID:                     b55a8200-0ab9-41b2-a8ba-06223cebf9e6
#     sensor:                          3A-FLORTD101
#     source:                          RS01SBPS-SF01A-3A-FLORTD101-streamed-flo...
#     sourceUrl:                       http://oceanobservatories.org/
#     standard_name_vocabulary:        NetCDF Climate and Forecast (CF) Metadat...
#     stream:                          flort_d_data_record
#     subsite:                         RS01SBPS
#     summary:                         Dataset Generated by Stream Engine from ...
#     time_coverage_end:               1970-01-01T00:00:03.634329599
#     time_coverage_resolution:        P1.81S
#     time_coverage_start:             1970-01-01T00:00:03.621593413
#     title:                           Data produced by Stream Engine version 1...
#     uuid:                            b55a8200-0ab9-41b2-a8ba-06223cebf9e6

# %%
zarrchlor=s3ds.sel(time=slice('2019-06-01', '2019-09-30'))
zarrchlor
# Out:
# <xarray.Dataset>
# Dimensions:                                          (time: 8121271)
# Coordinates:
#     int_ctd_pressure                                 (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     lat                                              (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     lon                                              (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#   * time                                             (time) datetime64[ns] 2019-06-01T00:00:00.339009024 ... 2019-09-27T18:41:51.008452096
# Data variables:
#     date_string                                      (time) <U1 dask.array<chunksize=(593361,), meta=np.ndarray>
#     deployment                                       (time) int32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     driver_timestamp                                 (time) datetime64[ns] dask.array<chunksize=(593361,), meta=np.ndarray>
#     fluorometric_cdom                                (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     fluorometric_cdom_qc_executed                    (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
#     fluorometric_cdom_qc_results                     (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
#     fluorometric_chlorophyll_a                       (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     fluorometric_chlorophyll_a_qc_executed           (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
#     fluorometric_chlorophyll_a_qc_results            (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
#     id                                               (time) <U36 dask.array<chunksize=(593361,), meta=np.ndarray>
#     ingestion_timestamp                              (time) datetime64[ns] dask.array<chunksize=(593361,), meta=np.ndarray>
#     internal_timestamp                               (time) datetime64[ns] dask.array<chunksize=(593361,), meta=np.ndarray>
#     measurement_wavelength_beta                      (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     measurement_wavelength_cdom                      (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     measurement_wavelength_chl                       (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     optical_backscatter                              (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     optical_backscatter_qc_executed                  (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
#     optical_backscatter_qc_results                   (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
#     port_timestamp                                   (time) datetime64[ns] dask.array<chunksize=(593361,), meta=np.ndarray>
#     practical_salinity                               (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     preferred_timestamp                              (time) <U36 dask.array<chunksize=(593361,), meta=np.ndarray>
#     raw_internal_temp                                (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     raw_signal_beta                                  (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     raw_signal_cdom                                  (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     raw_signal_chl                                   (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     seawater_scattering_coefficient                  (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     seawater_temperature                             (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     signal_1_offset                                  (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     signal_1_scale_factor                            (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     signal_2_offset                                  (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     signal_2_scale_factor                            (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     signal_3_offset                                  (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     signal_3_scale_factor                            (time) float32 dask.array<chunksize=(593361,), meta=np.ndarray>
#     time_string                                      (time) <U1 dask.array<chunksize=(593361,), meta=np.ndarray>
#     total_volume_scattering_coefficient              (time) float64 dask.array<chunksize=(593361,), meta=np.ndarray>
#     total_volume_scattering_coefficient_qc_executed  (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
#     total_volume_scattering_coefficient_qc_results   (time) uint8 dask.array<chunksize=(593361,), meta=np.ndarray>
# Attributes:
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     Notes:                           This netCDF product is a copy of the dat...
#     Owner:                           University of Washington Cabled Array Va...
#     acknowledgement:
#     cdm_data_type:                   Point
#     collection_method:               streamed
#     comment:                         Some of the metadata of this dataset has...
#     contributor_name:
#     contributor_role:
#     creator_email:
#     creator_name:                    Ocean Observatories Initiative
#     creator_url:                     http://oceanobservatories.org/
#     date_created:                    2019-11-12T23:42:08.675553
#     date_downloaded:                 2019-11-13T00:17:23.136299
#     date_modified:                   2019-11-12T23:42:08.675558
#     date_processed:                  2019-11-13T00:21:57.400125
#     featureType:                     point
#     feature_Type:                    point
#     geospatial_lat_max:              44.52897
#     geospatial_lat_min:              44.52897
#     geospatial_lat_resolution:       0.1
#     geospatial_lat_units:            degrees_north
#     geospatial_lon_max:              -125.38937
#     geospatial_lon_min:              -125.38937
#     geospatial_lon_resolution:       0.1
#     geospatial_lon_units:            degrees_east
#     geospatial_vertical_positive:    down
#     geospatial_vertical_resolution:  0.1
#     geospatial_vertical_units:       meters
#     history:                         2019-11-12T23:42:08.675491 generated fro...
#     id:                              RS01SBPS-SF01A-3A-FLORTD101-streamed-flo...
#     infoUrl:                         http://oceanobservatories.org/
#     institution:                     Ocean Observatories Initiative
#     keywords:
#     keywords_vocabulary:
#     license:
#     naming_authority:                org.oceanobservatories
#     nodc_template_version:           NODC_NetCDF_TimeSeries_Orthogonal_Templa...
#     node:                            SF01A
#     processing_level:                L2
#     project:                         Ocean Observatories Initiative
#     publisher_email:
#     publisher_name:                  Ocean Observatories Initiative
#     publisher_url:                   http://oceanobservatories.org/
#     references:                      More information can be found at http://...
#     requestUUID:                     b55a8200-0ab9-41b2-a8ba-06223cebf9e6
#     sensor:                          3A-FLORTD101
#     source:                          RS01SBPS-SF01A-3A-FLORTD101-streamed-flo...
#     sourceUrl:                       http://oceanobservatories.org/
#     standard_name_vocabulary:        NetCDF Climate and Forecast (CF) Metadat...
#     stream:                          flort_d_data_record
#     subsite:                         RS01SBPS
#     summary:                         Dataset Generated by Stream Engine from ...
#     time_coverage_end:               1970-01-01T00:00:03.634329599
#     time_coverage_resolution:        P1.81S
#     time_coverage_start:             1970-01-01T00:00:03.621593413
#     title:                           Data produced by Stream Engine version 1...
#     uuid:                            b55a8200-0ab9-41b2-a8ba-06223cebf9e6

# %%
zarrchlor.fluorometric_chlorophyll_a.plot()

# %%
from dask.diagnostics import ProgressBar

# %%
zarrchlor.plot.scatter(x='time', y='int_ctd_pressure', hue='fluorometric_chlorophyll_a')
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f5b6af96488> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     864     def draw(self, renderer):
#     865         self.set_sizes(self._sizes, self.figure.dpi)
# --> 866         Collection.draw(self, renderer)
#     867
#     868
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     327                 self._linewidths, self._linestyles,
#     328                 self._antialiaseds, self._urls,
# --> 329                 self._offset_position)
#     330
#     331         gc.restore()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/path.py in vertices(self)
#     195         )
#     196
# --> 197     @property
#     198     def vertices(self):
#     199         """
#
# KeyboardInterrupt:
